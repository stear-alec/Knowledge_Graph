# %%
import pandas as pd

# %%
data = pd.read_csv('query1.csv', header=None)

# %%
data
# Out:
#                                                     0  \
# 0     <http://erias.fr/oregano/compound/compound_323>
# 1     <http://erias.fr/oregano/compound/compound_323>
# 2     <http://erias.fr/oregano/compound/compound_323>
# 3     <http://erias.fr/oregano/compound/compound_323>
# 4     <http://erias.fr/oregano/compound/compound_323>
# ...                                               ...
# 3924  <http://erias.fr/oregano/compound/compound_659>
# 3925  <http://erias.fr/oregano/compound/compound_659>
# 3926  <http://erias.fr/oregano/compound/compound_659>
# 3927  <http://erias.fr/oregano/compound/compound_659>
# 3928  <http://erias.fr/oregano/compound/compound_659>
#
#                                                  1  \
# 0     <http://erias.fr/oregano/#decrease_efficacy>
# 1     <http://erias.fr/oregano/#decrease_efficacy>
# 2     <http://erias.fr/oregano/#decrease_efficacy>
# 3     <http://erias.fr/oregano/#decrease_efficacy>
# 4     <http://erias.fr/oregano/#decrease_efficacy>
# ...

# %% [markdown]
# # Remove the rows with garbage.

# %%
data[3890:3900]
# Out:
#                                                     0  \
# 3890  <http://erias.fr/oregano/compound/compound_718>
# 3891  <http://erias.fr/oregano/compound/compound_659>
# 3892  <http://erias.fr/oregano/compound/compound_659>
# 3893  <http://erias.fr/oregano/compound/compound_659>
# 3894  <http://erias.fr/oregano/compound/compound_659>
# 3895  <http://erias.fr/oregano/compound/compound_659>
# 3896  <http://erias.fr/oregano/compound/compound_659>
# 3897  <http://erias.fr/oregano/compound/compound_659>
# 3898  <http://erias.fr/oregano/compound/compound_659>
# 3899  <http://erias.fr/oregano/compound/compound_659>
#
#                                                       1  \
# 3890  <http://www.w3.org/1999/02/22-rdf-syntax-ns/#t...
# 3891                     <http://erias.fr/oregano/#atc>
# 3892               <http://erias.fr/oregano/#bindingdb>
# 3893                   <http://erias.fr/oregano/#chebi>
# 3894                   <http://erias.fr/oregano/#chebi>
# ...

# %%
v = data[data[2].str.contains('oregano/')]
len(v )
# Out:
# 3767

# %% [markdown]
# # Clean the strings

# %%
data = v

# %%
data
# Out:
#                                                     0  \
# 0     <http://erias.fr/oregano/compound/compound_323>
# 1     <http://erias.fr/oregano/compound/compound_323>
# 2     <http://erias.fr/oregano/compound/compound_323>
# 3     <http://erias.fr/oregano/compound/compound_323>
# 4     <http://erias.fr/oregano/compound/compound_323>
# ...                                               ...
# 3924  <http://erias.fr/oregano/compound/compound_659>
# 3925  <http://erias.fr/oregano/compound/compound_659>
# 3926  <http://erias.fr/oregano/compound/compound_659>
# 3927  <http://erias.fr/oregano/compound/compound_659>
# 3928  <http://erias.fr/oregano/compound/compound_659>
#
#                                                  1  \
# 0     <http://erias.fr/oregano/#decrease_efficacy>
# 1     <http://erias.fr/oregano/#decrease_efficacy>
# 2     <http://erias.fr/oregano/#decrease_efficacy>
# 3     <http://erias.fr/oregano/#decrease_efficacy>
# 4     <http://erias.fr/oregano/#decrease_efficacy>
# ...

# %%
data['subject'] = data[0].str.split('oregano/compound/').str[1]
data['object'] = data[1].str.split('/oregano/#').str[1]
data['predicat'] = data[2].str.split('oregano/compound/').str[1]
# Out:
# /tmp/ipykernel_164429/607774588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['subject'] = data[0].str.split('oregano/compound/').str[1]
# /tmp/ipykernel_164429/607774588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['object'] = data[1].str.split('/oregano/#').str[1]
# /tmp/ipykernel_164429/607774588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data = data.drop([0, 1, 2], axis=1)

# %%
data
# Out:
#             subject              object         predicat
# 0     compound_323>  decrease_efficacy>  compound_11377>
# 1     compound_323>  decrease_efficacy>  compound_11624>
# 2     compound_323>  decrease_efficacy>   compound_1164>
# 3     compound_323>  decrease_efficacy>   compound_1166>
# 4     compound_323>  decrease_efficacy>  compound_12222>
# ...             ...                 ...              ...
# 3924  compound_659>  decrease_efficacy>   compound_1309>
# 3925  compound_659>  decrease_efficacy>   compound_1310>
# 3926  compound_659>  decrease_efficacy>   compound_1311>
# 3927  compound_659>  decrease_efficacy>   compound_1327>
# 3928  compound_659>  decrease_efficacy>   compound_1330>
#
# [3767 rows x 3 columns]

# %%
data['predicat'] = data['predicat'].str[:-1]
data['object'] = data['object'].str[:-1]
data['subject'] = data['subject'].str[:-1]

# %%
data
# Out:
#            subject             object        predicat
# 0     compound_323  decrease_efficacy  compound_11377
# 1     compound_323  decrease_efficacy  compound_11624
# 2     compound_323  decrease_efficacy   compound_1164
# 3     compound_323  decrease_efficacy   compound_1166
# 4     compound_323  decrease_efficacy  compound_12222
# ...            ...                ...             ...
# 3924  compound_659  decrease_efficacy   compound_1309
# 3925  compound_659  decrease_efficacy   compound_1310
# 3926  compound_659  decrease_efficacy   compound_1311
# 3927  compound_659  decrease_efficacy   compound_1327
# 3928  compound_659  decrease_efficacy   compound_1330
#
# [3767 rows x 3 columns]

# %%
data.to_csv('data_query1.csv', index=False)
